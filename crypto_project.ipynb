# %%
# API call
import requests

# Endpoint
url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/category"

# Headers for the request
headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': 'de7da518-a4aa-41d6-8c2c-d51fc2e14b6a',
}

# Query parameters
params = {
    'id': '6363a6c9cd197958bb543bf0'
}

# Make the API request
response = requests.get(url, headers=headers, params=params)

# Check the response
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# {'status': {'timestamp': '2023-10-03T13:27:15.142Z', 'error_code': 0, 'error_message': None, 'elapsed': 192, 'credit_count': 1, 'notice': None}, 'data': {'id': '6363a6c9cd197958bb543bf0', 'name': 'Soccer', 'title': 'Soccer', 'description': 'Soccer', 'num_tokens': 52, 'last_updated': '2022-11-03T11:36:20.885Z', 'avg_price_change': -1.743516808064516, 'market_cap': 137054812.99, 'market_cap_change': -1.097983870967742, 'volume': 57458616.77590218, 'volume_change': 70.97228387096776, 'coins': [{'id': 5225, 'name': 'FC Barcelona Fan Token', 'symbol': 'BAR', 'slug': 'fc-barcelona-fan-token', 'num_market_pairs': 40, 'date_added': '2020-06-24T00:00:00.000Z', 'tags': ['sports', 'fan-token', 'binance-launchpad', 'soccer'], 'max_supply': 40000000, 'circulating_supply': 10400012, 'total_supply': 40000000, 'platform': {'id': 4066, 'name': 'Chiliz', 'symbol': 'CHZ', 'slug': 'chiliz', 'token_address': '0xecc000ebd318bee2a052eb174a71faf2c3c9e898'}, 'is_active': 1, 'infinite_supply': False, 'cmc_rank': 546, 'is_fiat': 0, 'self_reported_circulating_supply': 10400084, 'self_reported_market_cap': 23027145.283801917, 'tvl_ratio': None, 'last_updated': '2023-10-03T13:25:00.000Z', 'quote': {'USD': {'price': 2.214130701617594, 'volume_24h': 1815504.16348964, 'volume_change_24h': 58.7216, 'percent_change_1h': 0.05211505, 'percent_change_24h': -1.10470968, 'percent_change_7d': -0.55502037, 'percent_change_30d': -12.01886494, 'percent_change_60d': -19.87771653, 'percent_change_90d': -6.58076871, 'market_cap': 23026985.866391398, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 88565228.06, 'tvl': None, 'last_updated': '2023-10-03T13:25:00.000Z'}}}, {'id': 5309, 'name': 'OG Fan Token', 'symbol': 'OG', 'slug': 'og-fan-token', 'num_market_pairs': 61, 'date_added': '2020-03-12T00:00:00.000Z', 'tags': ['sports', 'fan-token', 'binance-launchpool', 'soccer'], 'max_supply': None, 'circulating_supply': 3858117, 'total_supply': 5000000, 'platform': {'id': 4066, 'name': 'Chiliz', 'symbol': 'CHZ', 'slug': 'chiliz', 'token_address': '0x7bcb8bB59298ba3Aed51a6a0348187Ba4ffD1c69'}, 'is_active': 1, 'infinite_supply': False, 'cmc_rank': 596, 'is_fiat': 0, 'self_reported_circulating_supply': 3858117, 'self_reported_market_cap': 17702161.237967856, 'tvl_ratio': None, 'last_updated': '2023-10-03T13:25:00.000Z', 'quote': {'USD': {'price': 4.588290411609564, 'volume_24h': 29746824.86831989, 'volume_change_24h': 348.997, 'percent_change_1h': 0.24323228, 'percent_change_24h': 0.84220798, 'percent_change_7d': 4.07525201, 'percent_change_30d': 0.05764204, 'percent_change_60d': 17.99544396, 'percent_change_90d': 8.18398697, 'market_cap': 17702161.237967856, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 22941452.06, 'tvl': None, 'last_updated': '2023-10-03T13:25:00.000Z'}}}, {'id': 10049, 'name': 'Manchester City Fan Token', 'symbol': 'CITY', 'slug': 'manchester-city-fan-token', 'num_market_pairs': 47, 'date_added': '2021-05-25T00:00:00.000Z', 'tags': ['sports', 'fan-token', 'binance-launchpool', 'soccer'], 'max_supply': 19740000, 'circulating_supply': 5792132, 'total_supply': 19740000, 'is_active': 1, 'infinite_supply': False, 'platform': None, 'cmc_rank': 614, 'is_fiat': 0, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-10-03T13:25:00.000Z', 'quote': {'USD': {'price': 2.8351745567911983, 'volume_24h': 1664184.89394798, 'volume_change_24h': 31.4192, 'percent_change_1h': 0.55543409, 'percent_change_24h': -0.90067161, 'percent_change_7d': -0.30882932, 'percent_change_30d': -5.02116611, 'percent_change_60d': -18.81290655, 'percent_change_90d': -5.5271055, 'market_cap': 16421705.275976118, 'market_cap_dominance': 0.0015, 'fully_diluted_market_cap': 55966345.75, 'tvl': None, 'last_updated': '2023-10-03T13:25:00.000Z'}}}, {'id': 5226, 'name': 'Paris Saint-Germain Fan Token', 'symbol': 'PSG', 'slug': 'paris-saint-germain-fan-token', 'num_market_pairs': 56, 'date_added': '2020-06-11T00:00:00.000Z', 'tags ...

# %%
import pandas as pd

# Convert the 'data' key from the JSON response into a DataFrame
df = pd.DataFrame(data['data'])
df.head()
# Out:
#                          id    name   title description  num_tokens  \
# 0  6363a6c9cd197958bb543bf0  Soccer  Soccer      Soccer          52
# 1  6363a6c9cd197958bb543bf0  Soccer  Soccer      Soccer          52
# 2  6363a6c9cd197958bb543bf0  Soccer  Soccer      Soccer          52
# 3  6363a6c9cd197958bb543bf0  Soccer  Soccer      Soccer          52
# 4  6363a6c9cd197958bb543bf0  Soccer  Soccer      Soccer          52
#
#                last_updated  avg_price_change    market_cap  \
# 0  2022-11-03T11:36:20.885Z         -1.743517  1.370548e+08
# 1  2022-11-03T11:36:20.885Z         -1.743517  1.370548e+08
# 2  2022-11-03T11:36:20.885Z         -1.743517  1.370548e+08
# 3  2022-11-03T11:36:20.885Z         -1.743517  1.370548e+08
# 4  2022-11-03T11:36:20.885Z         -1.743517  1.370548e+08
#
#    market_cap_change        volume  volume_change  \
# 0          -1.097984  5.745862e+07      70.972284
# 1          -1.097984  5.745862e+07      70.972284
# 2          -1.097984  5.745862e+07      70.972284
# 3          -1.097984  5.745862e+07      70.972284
# 4          -1.097984  5.745862e+07      70.972284
#
#                                                coins
# 0  {'id': 5225, 'name': 'FC Barcelona Fan Token',...
# 1  {'id': 5309, 'name': 'OG Fan Token', 'symbol':...
# 2  {'id': 10049, 'name': 'Manchester City Fan Tok...
# 3  {'id': 5226, 'name': 'Paris Saint-Germain Fan ...
# 4  {'id': 5224, 'name': 'Juventus Fan Token', 'sy...

# %%
coins_df = pd.DataFrame(df['coins'].tolist())
coins_df.head()
# Out:
#       id                           name symbol                           slug  \
# 0   5225         FC Barcelona Fan Token    BAR         fc-barcelona-fan-token
# 1   5309                   OG Fan Token     OG                   og-fan-token
# 2  10049      Manchester City Fan Token   CITY      manchester-city-fan-token
# 3   5226  Paris Saint-Germain Fan Token    PSG  paris-saint-germain-fan-token
# 4   5224             Juventus Fan Token    JUV             juventus-fan-token
#
#    num_market_pairs                date_added  \
# 0                40  2020-06-24T00:00:00.000Z
# 1                61  2020-03-12T00:00:00.000Z
# 2                47  2021-05-25T00:00:00.000Z
# 3                56  2020-06-11T00:00:00.000Z
# 4                46  2020-04-22T00:00:00.000Z
#
#                                               tags  max_supply  \
# 0   [sports, fan-token, binance-launchpad, soccer]  40000000.0
# 1  [sports, fan-token, binance-launchpool, soccer]         NaN
# 2  [sports, fan-token, binance-launchpool, soccer]  19740000.0
# 3  [sports, fan-token, binance-launchpool, soccer]  20000000.0
# 4  [sports, fan-token, binance-launchpool, soccer]  20000000.0
#
#    circulating_supply  total_supply  \
# 0          10400012.0      40000000
# 1           3858117.0       5000000
# 2           5792132.0      19740000
# 3           4734357.0      20000000
# 4           5724314.0      20000000
#
#                                             platform  is_active  \
# 0  {'id': 4066, 'name': 'Chiliz', 'symbol': 'CHZ'...          1
# 1  {'id': 4066, 'name': 'Chiliz', 'symbol': 'CHZ'...          1
# 2                                               None          1
# 3  {'id': 4066, 'name': 'Chiliz', 'symbol': 'CHZ'...          1
# 4  {'id': 4066, 'name': 'Chiliz', 'symbol': 'CHZ'...          1
#
#    infinite_supply  cmc_rank  is_fiat  self_reported_circulating_supply  \
# 0            False     546.0        0                        10400084.0
# 1            False     596.0        0                         3858117.0
# 2            False     614.0        0                               NaN
# 3            False     655.0        0                         4734357.0
# 4            False     710.0        0                         5724315.0
#
#    self_reported_market_cap tvl_ratio              last_updated  \
# 0              2.302715e+07      None  2023-10-03T13:25:00.000Z
# 1              1.770216e+07      None  2023-10-03T13:25:00.000Z
# 2                       NaN      None  2023-10-03T13:25:00.000Z
# 3              1.422491e+07      None  2023-10-03T13:25:00.000Z
# 4              1.123646e+07      None  2023-10-03T13:25:00.000Z
#
#                                                quote
# 0  {'USD': {'price': 2.214130701617594, 'volume_2...
# 1  {'USD': {'price': 4.588290411609564, 'volume_2...
# 2  {'USD': {'price': 2.8351745567911983, 'volume_...
# 3  {'USD': {'price': 3.004612409171802, 'volume_2...
# 4  {'USD': {'price': 1.9629350614543304, 'volume_...

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# Apply the flatten_json function to the 'quote' column
flattened_quotes = coins_df['quote'].apply(flatten_json)

# Convert the Series of dictionaries into a DataFrame
flattened_quote_df = pd.DataFrame(flattened_quotes.tolist())

# Concatenate the original coins_df and the flattened_quote_df
result_df = pd.concat([coins_df.drop(columns=['quote']), flattened_quote_df], axis=1)

result_df.head()
# Out:
#       id                           name symbol                           slug  \
# 0   5225         FC Barcelona Fan Token    BAR         fc-barcelona-fan-token
# 1   5309                   OG Fan Token     OG                   og-fan-token
# 2  10049      Manchester City Fan Token   CITY      manchester-city-fan-token
# 3   5226  Paris Saint-Germain Fan Token    PSG  paris-saint-germain-fan-token
# 4   5224             Juventus Fan Token    JUV             juventus-fan-token
#
#    num_market_pairs                date_added  \
# 0                40  2020-06-24T00:00:00.000Z
# 1                61  2020-03-12T00:00:00.000Z
# 2                47  2021-05-25T00:00:00.000Z
# 3                56  2020-06-11T00:00:00.000Z
# 4                46  2020-04-22T00:00:00.000Z
#
#                                               tags  max_supply  \
# 0   [sports, fan-token, binance-launchpad, soccer]  40000000.0
# 1  [sports, fan-token, binance-launchpool, soccer]         NaN
# 2  [sports, fan-token, binance-launchpool, soccer]  19740000.0
# 3  [sports, fan-token, binance-launchpool, soccer]  20000000.0
# 4  [sports, fan-token, binance-launchpool, soccer]  20000000.0
#
#    circulating_supply  total_supply  ... USD_percent_change_24h  \
# 0          10400012.0      40000000  ...              -1.104710
# 1           3858117.0       5000000  ...               0.842208
# 2           5792132.0      19740000  ...              -0.900672
# 3           4734357.0      20000000  ...              -0.530535
# 4           5724314.0      20000000  ...              -1.159106
#
#    USD_percent_change_7d  USD_percent_change_30d  USD_percent_change_60d  \
# 0              -0.555020              -12.018865              -19.877717
# 1               4.075252                0.057642               17.995444
# 2              -0.308829               -5.021166              -18.812907
# 3              -0.484660               -5.860531              -21.237543
# 4              -0.276514               -5.430859              -18.532652
#
#    USD_percent_change_90d  USD_market_cap  USD_market_cap_dominance  \
# 0               -6.580769    2.302699e+07                    0.0000
# 1                8.183987    1.770216e+07                    0.0000
# 2               -5.527106    1.642171e+07                    0.0015
# 3              -11.655185    1.422491e+07                    0.0013
# 4               -9.169929    1.123646e+07                    0.0000
#
#   USD_fully_diluted_market_cap USD_tvl          USD_last_updated
# 0                  88565228.06    None  2023-10-03T13:25:00.000Z
# 1                  22941452.06    None  2023-10-03T13:25:00.000Z
# 2                  55966345.75    None  2023-10-03T13:25:00.000Z
# 3                  60092248.18    None  2023-10-03T13:25:00.000Z
# 4                  39258701.23    None  2023-10-03T13:25:00.000Z
#
# [5 rows x 33 columns]

# %%
fan_tokens = result_df[['id', 'name', 'symbol',
       'slug', 'last_updated', 'USD_price', 'USD_volume_24h',
       'USD_volume_change_24h', 'USD_percent_change_1h',
       'USD_percent_change_24h', 'USD_percent_change_7d',
       'USD_percent_change_30d', 'USD_percent_change_60d',
       'USD_percent_change_90d', 'USD_market_cap', 'USD_market_cap_dominance',
       'USD_fully_diluted_market_cap', 'USD_tvl', 'USD_last_updated']]

fan_tokens
# Out:
#        id                                        name         symbol  \
# 0    5225                      FC Barcelona Fan Token            BAR
# 1    5309                                OG Fan Token             OG
# 2   10049                   Manchester City Fan Token           CITY
# 3    5226               Paris Saint-Germain Fan Token            PSG
# 4    5224                          Juventus Fan Token            JUV
# 5    8538                          AC Milan Fan Token            ACM
# 6    5227                Atletico De Madrid Fan Token            ATM
# 7    5228                       Galatasaray Fan Token            GAL
# 8    5229                           AS Roma Fan Token            ASR
# 9    7637                       Trabzonspor Fan Token            TRA
# 10   3663                          Footballcoin (XFC)            XFC
# 11  11198                                     TopGoal           GOAL
# 12  10430    Argentine Football Association Fan Token            ARG
# 13   9507                      Göztepe S.K. Fan Token            GOZ
# 14   9172      Professional Fighters League Fan Token            PFL
# 15   8341                        Young Boys Fan Token            YBO
# 16   8884               İstanbul Başakşehir Fan Token           IBFK
# 17   8340                     Natus Vincere Fan Token           NAVI
# 18   9509                      Legia Warsaw Fan Token            LEG
# 19   8882                          Alliance Fan Token            ALL
# 20   7638                            Apollon Limassol            APL
# 21   9508              Universidad de Chile Fan Token            UCH
# 22   7639                 Club Atletico Independiente            CAI
# 23   8883  Sint-Truidense Voetbalvereniging Fan Token            STV
# 24   7636                     Team Heretics Fan Token             TH
# 25  20575   Peruvian National Football Team Fan Token           FPFT
# 26   8885                     Novara Calcio Fan Token            NOV
# 27   9510                   Fortuna Sittard Fan Token            FOR
# 28  14687                             Soccer Infinity          SOCIN
# 29  20741                             Football Battle            FBL
# 30  21098                             World Cup Token            WCT
# 31  21278                                 FIFA Champs         CHAMPS
# 32  21302                              World Football           WOFO
# 33  21340                         FIFA World Cup Fans           FIFA
# 34  11254                                Minifootball   MINIFOOTBALL
# 35  11326                                   SoccerHub            SCH
# 36  13985                                  FootBallGo        FGSPORT
# 37   9910                              Football Stars  FootballStars
# 38  22197                                   SoccerInu         SOCCER
# 39  21962                               WORLD CUP INU            WCI
# 40  22323                                    Fifa Inu           FINU
# 41  21985                                  FIFA-Laeeb          LAEEB
# 42  22361                            World Cup Willie         WILLIE
# 43  22159                      Football Decentralized            FBD
# 44  22477                             Shiba World Cup            SWC
# 45  21425                                   FiFaSport            FFS
# 46  22479                                    FIFADOGE          FDOGE
# 47  21657                              World Bet Club            WBT
# 48  22631                                    Futuball             FB
# 49  21782                               Soccer Galaxy            SOG
# 50  22671                               World Cup Pot            WCP
#
#                                          slug              last_updated  \
# 0                      fc-barcelona-fan-token  2023-10-03T13:25:00.000Z
# 1                                og-fan-token  2023-10-03T13:25:00.000Z
# 2                   manchester-city-fan-token  2023-10-03T13:25:00.000Z
# 3               paris-saint-germain-fan-token  2023-10-03T13:25:00.000Z
# 4                          juventus-fan-token  2023-10-03T13:25:00.000Z
# 5                          ac-milan-fan-token  2023-10-03T13:25:00.000Z
# 6                atletico-de-madrid-fan-token  2023-10-03T13:25:00.000Z
# 7                       galatasaray-fan-token  2023-10-03T13:25:00.000Z
# 8                           as-roma-fan-token  2023-10-03T13:25:00.000Z
# 9                       trabzonspor-fan-token  2023-10-03T13:25:00.000Z
