# %%
# Initial setup from the provided code
base_url = "https://api.fanmarketcap.com/api/v1/markets/"
days_value = "max"  # Replace with one of the available values, e.g., "7d"

headers = {
    'X-API-KEY': '5fd18d6c9f8ebf5f7abdcb8030f257de44606258'  # Replace with your actual API key
}

# List of slugs to fetch data for
slugs = [
    "fc-barcelona-fan-token", "galatasaray-fan-token", "as-roma-fan-token", 
    "manchester-city-fan-token", "lazio-fan-token", "paris-saint-germain-fan-token", 
    "fc-porto-fan-token", "juventus-fan-token", "ac-milan-fan-token", "arsenal-fan-token", 
    "atletico-madrid-fan-token", "trabzonspor-fan-token", "inter-milan-fan-token", 
    "napoli-fan-token", "valencia-fan-token", "young-boys-fan-token", "legia-warsaw-fan-token", 
    "real-sociedad-fan-token", "as-monaco-fan-token", "sevilla-fc-fan-token", "fenerbahce-fan-token", 
    "besiktas-fan-token", "aston-villa-fan-token", "everton-fc-fan-token", "dinamo-zagreb-fan-token", 
    "leeds-united-fan-token", "bologna-fc-fan-token", "udinese-fan-token"
]

# Dictionary to store data for each slug
data_dict = {}

import pandas as pd

# List to store individual dataframes
df_list = []

# Loop through each slug and make the API call
for slug in slugs:
    endpoint_url = f"{base_url}{slug}/{days_value}/"
    response = requests.get(endpoint_url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        
        # Convert the data to a dataframe
        df = pd.DataFrame(data)
        
        # Add a new column 'slug' to the dataframe
        df['slug'] = slug

        # Convert the date format
        df['date'] = pd.to_datetime(df['date'], unit='ms').dt.strftime('%Y-%m-%d')
        
        # Create the 'token_name' column
        df['token_name'] = df['slug'].str.replace('-', ' ')

          # Create the 'team_name' column
        df['team_name'] = df['token_name'].str.replace('fan token', '').str.strip()
        
        df_list.append(df)
    else:
        print(f"Error for slug {slug}: {response.status_code}: {response.text}")

# Concatenate all the dataframes in the list into a single dataframe
final_df = pd.concat(df_list, ignore_index=True)

# Remove the 'market_cap' column
final_df = final_df.drop(columns=['market_cap'])

# %%
final_df
# Out:
#           price  market_cap         volume        date  \
# 0      6.261206         0.0  311876.954013  2020-06-25
# 1      6.261206         0.0  311876.954013  2020-06-26
# 2      5.804014         0.0  300380.939093  2020-06-27
# 3      4.971234         0.0  318666.015727  2020-06-28
# 4      5.050388         0.0  331790.297430  2020-06-29
# ...         ...         ...            ...         ...
# 21783  0.949253         0.0   54274.487772  2023-09-30
# 21784  0.966765         0.0   60013.874586  2023-10-01
# 21785  0.986123         0.0   56180.396510  2023-10-02
# 21786  0.952171         0.0   52872.125087  2023-10-03
# 21787  0.898068         0.0   49497.937829  2023-10-03
#
#                          slug              token_name     team_name
# 0      fc-barcelona-fan-token  fc barcelona fan token  fc barcelona
# 1      fc-barcelona-fan-token  fc barcelona fan token  fc barcelona
# 2      fc-barcelona-fan-token  fc barcelona fan token  fc barcelona
# 3      fc-barcelona-fan-token  fc barcelona fan token  fc barcelona
# 4      fc-barcelona-fan-token  fc barcelona fan token  fc barcelona
# ...                       ...                     ...           ...
# 21783       udinese-fan-token       udinese fan token       udinese
# 21784       udinese-fan-token       udinese fan token       udinese
# 21785       udinese-fan-token       udinese fan token       udinese
# 21786       udinese-fan-token       udinese fan token       udinese
# 21787       udinese-fan-token       udinese fan token       udinese
#
# [21788 rows x 7 columns]
