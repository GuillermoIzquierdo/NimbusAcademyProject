# %%
# API call
import requests

# Endpoint
url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/category"

# Headers for the request
headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': 'de7da518-a4aa-41d6-8c2c-d51fc2e14b6a',
}

# Query parameters
params = {
    'id': '6363a6c9cd197958bb543bf0'
}

# Make the API request
response = requests.get(url, headers=headers, params=params)

# Check the response
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# {'status': {'timestamp': '2023-10-03T13:43:34.782Z', 'error_code': 0, 'error_message': None, 'elapsed': 313, 'credit_count': 1, 'notice': None}, 'data': {'id': '6363a6c9cd197958bb543bf0', 'name': 'Soccer', 'title': 'Soccer', 'description': 'Soccer', 'num_tokens': 52, 'last_updated': '2022-11-03T11:36:20.885Z', 'avg_price_change': -2.137073958666667, 'market_cap': 136867373.42000005, 'market_cap_change': -1.4743066666666667, 'volume': 57824659.43997858, 'volume_change': 73.07135999999998, 'coins': [{'id': 5225, 'name': 'FC Barcelona Fan Token', 'symbol': 'BAR', 'slug': 'fc-barcelona-fan-token', 'num_market_pairs': 40, 'date_added': '2020-06-24T00:00:00.000Z', 'tags': ['sports', 'fan-token', 'binance-launchpad', 'soccer'], 'max_supply': 40000000, 'circulating_supply': 10400012, 'total_supply': 40000000, 'platform': {'id': 4066, 'name': 'Chiliz', 'symbol': 'CHZ', 'slug': 'chiliz', 'token_address': '0xecc000ebd318bee2a052eb174a71faf2c3c9e898'}, 'is_active': 1, 'infinite_supply': False, 'cmc_rank': 544, 'is_fiat': 0, 'self_reported_circulating_supply': 10400084, 'self_reported_market_cap': 23070949.01974707, 'tvl_ratio': None, 'last_updated': '2023-10-03T13:42:00.000Z', 'quote': {'USD': {'price': 2.2183425652857296, 'volume_24h': 1799144.71074936, 'volume_change_24h': 54.3306, 'percent_change_1h': 0.34832338, 'percent_change_24h': -0.74314548, 'percent_change_7d': -0.15763766, 'percent_change_30d': -11.81893222, 'percent_change_60d': -19.83671335, 'percent_change_90d': -6.23424994, 'market_cap': 23070789.299082372, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 88733702.61, 'tvl': None, 'last_updated': '2023-10-03T13:42:00.000Z'}}}, {'id': 5309, 'name': 'OG Fan Token', 'symbol': 'OG', 'slug': 'og-fan-token', 'num_market_pairs': 61, 'date_added': '2020-03-12T00:00:00.000Z', 'tags': ['sports', 'fan-token', 'binance-launchpool', 'soccer'], 'max_supply': None, 'circulating_supply': 3858117, 'total_supply': 5000000, 'platform': {'id': 4066, 'name': 'Chiliz', 'symbol': 'CHZ', 'slug': 'chiliz', 'token_address': '0x7bcb8bB59298ba3Aed51a6a0348187Ba4ffD1c69'}, 'is_active': 1, 'infinite_supply': False, 'cmc_rank': 595, 'is_fiat': 0, 'self_reported_circulating_supply': 3858117, 'self_reported_market_cap': 17744479.793824993, 'tvl_ratio': None, 'last_updated': '2023-10-03T13:42:00.000Z', 'quote': {'USD': {'price': 4.599259118846057, 'volume_24h': 30032788.70003908, 'volume_change_24h': 350.4021, 'percent_change_1h': 1.12194252, 'percent_change_24h': 1.25204845, 'percent_change_7d': 4.26180943, 'percent_change_30d': -1.35825818, 'percent_change_60d': 17.7885479, 'percent_change_90d': 9.09134546, 'market_cap': 17744479.793824993, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 22996295.59, 'tvl': None, 'last_updated': '2023-10-03T13:42:00.000Z'}}}, {'id': 10049, 'name': 'Manchester City Fan Token', 'symbol': 'CITY', 'slug': 'manchester-city-fan-token', 'num_market_pairs': 47, 'date_added': '2021-05-25T00:00:00.000Z', 'tags': ['sports', 'fan-token', 'binance-launchpool', 'soccer'], 'max_supply': 19740000, 'circulating_supply': 5792132, 'total_supply': 19740000, 'is_active': 1, 'infinite_supply': False, 'platform': None, 'cmc_rank': 615, 'is_fiat': 0, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-10-03T13:42:00.000Z', 'quote': {'USD': {'price': 2.8381098615330997, 'volume_24h': 1666075.82980533, 'volume_change_24h': 29.0368, 'percent_change_1h': 0.58889558, 'percent_change_24h': -0.77383897, 'percent_change_7d': -0.08711812, 'percent_change_30d': -4.87457462, 'percent_change_60d': -18.67599107, 'percent_change_90d': -5.38329888, 'market_cap': 16438706.948501436, 'market_cap_dominance': 0.0015, 'fully_diluted_market_cap': 56024288.67, 'tvl': None, 'last_updated': '2023-10-03T13:42:00.000Z'}}}, {'id': 5226, 'name': 'Paris Saint-Germain Fan Token', 'symbol': 'PSG', 'slug': 'paris-saint-germain-fan-token', 'num_market_pairs': 56, 'date_added': '2020-06-11T00:00:00.000 ...

# %%
import pandas as pd

# Convert the 'data' key from the JSON response into a DataFrame
df = pd.DataFrame(data['data'])

# %%
coins_df = pd.DataFrame(df['coins'].tolist())

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# Apply the flatten_json function to the 'quote' column
flattened_quotes = coins_df['quote'].apply(flatten_json)

# Convert the Series of dictionaries into a DataFrame
flattened_quote_df = pd.DataFrame(flattened_quotes.tolist())

# Concatenate the original coins_df and the flattened_quote_df
result_df = pd.concat([coins_df.drop(columns=['quote']), flattened_quote_df], axis=1)

# %%
fan_tokens = result_df[['id', 'name', 'symbol',
       'slug', 'last_updated', 'USD_price', 'USD_volume_24h',
       'USD_volume_change_24h', 'USD_percent_change_1h',
       'USD_percent_change_24h', 'USD_percent_change_7d',
       'USD_percent_change_30d', 'USD_percent_change_60d',
       'USD_percent_change_90d', 'USD_market_cap', 'USD_market_cap_dominance',
       'USD_fully_diluted_market_cap', 'USD_tvl', 'USD_last_updated']]
